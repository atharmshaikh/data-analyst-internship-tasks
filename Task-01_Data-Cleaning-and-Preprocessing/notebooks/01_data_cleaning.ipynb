# %% [markdown]
# # Task 01 – Data Cleaning and Preprocessing
#
# **Role:** Data Analyst Intern
# **Objective:** Clean and prepare raw sales data for analysis, SQL querying, and dashboard development.
#
# This notebook demonstrates the data cleaning workflow using reusable
# production-ready Python modules from the `data_cleaning` package.

# %%
from pathlib import Path

from data_cleaning.io import load_csv
from data_cleaning.cleaning import inspect, clean
from data_cleaning.features import add_features

# %%
BASE_DIR = Path("..")
RAW_DATA_PATH = BASE_DIR / "data" / "raw" / "sales_data_sample.csv"

# %%
df_raw = load_csv(RAW_DATA_PATH)
df_raw.head()

# %%
inspect(df_raw)

# %%
df_cleaned = clean(df_raw)
df_cleaned.head()

# %%
df_final = add_features(df_cleaned)
df_final.head()

# %%
df_final.info()

# %% [markdown]
# ## Outcome
#
# The raw sales dataset has been successfully cleaned and transformed into a
# structured format suitable for:
#
# - Exploratory Data Analysis (EDA)
# - SQL-based analysis
# - Power BI dashboards
# - Future machine learning tasks
#
# This cleaned dataset serves as the data foundation for subsequent internship tasks.

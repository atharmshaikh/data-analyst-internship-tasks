# %% [markdown]
# # Task 01 – Data Cleaning and Preprocessing
#
# **Role:** Data Analyst Intern
# **Objective:** Clean and prepare raw sales data for analysis and dashboard creation.

# %%
import sys
import pandas as pd

# Allow notebook to access scripts folder
sys.path.append("../scripts")

from data_cleaning_and_preprocessing import (
    load_data,
    inspect_data,
    clean_data,
    feature_engineering
)

# %%
df = load_data("../data/sales_data_sample.csv")
df.head()

# %% [markdown]
# inspect_data(df)

# %%
df_final = feature_engineering(df_cleaned)
df_final.head()

# %% [markdown]
# ## Outcome
#
# The dataset has been successfully cleaned and prepared for:
# - Exploratory Data Analysis (EDA)
# - SQL analysis
# - Dashboard development (Power BI)
#
# This cleaned dataset is used in subsequent internship tasks.
